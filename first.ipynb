# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
students=pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
students.loc[students.gender=="female"]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ms=students["writing score"].mean()

# %%
students.loc[students["writing score"]>ms]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data=pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.loc[data.lunch=="standard",["reading score","math score","writing score"]].var()
# Out:
# reading score    191.285560
# math score       186.418089
# writing score    205.620887
# dtype: float64

# %%
data=data.rename(columns={"paretal level of education":"parents_ed","test preparation course": "test_course","math score":"math_score",
                          "reading score":"read_score","write_socre":"write_score"})

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_course  math_score  read_score  write_score
# 0          none          72          72           74
# ...

# %%
data.query("gender=='female'| write>80")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_course  math  read  write
# 0          none    72    72     74
# 1     completed    69    90     88
# ...

# %%
list(data)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test_course',
#  'math',
#  'read',
#  'write']

# %%
score=[i for i in list(data) if "score" in i]

# %%
data[score]
# Out:
#      math_score  read_score  write_score
# 0            72          72           74
# 1            69          90           88
# 2            90          95           93
# 3            47          57           44
# 4            76          78           75
# ..          ...         ...          ...
# 995          88          99           95
# 996          62          55           55
# 997          59          71           65
# 998          68          78           77
# 999          77          86           86
#
# [1000 rows x 3 columns]

# %%
data.filter(like="score")
# Out:
#      math_score  read_score  write_score
# 0            72          72           74
# 1            69          90           88
# 2            90          95           93
# 3            47          57           44
# 4            76          78           75
# ..          ...         ...          ...
# 995          88          99           95
# 996          62          55           55
# 997          59          71           65
# 998          68          78           77
# 999          77          86           86
#
# [1000 rows x 3 columns]

# %%
data.groupby(["race/ethnicity","gender"]).aggregate({"math_score":"mean","read_score":"mean"}).loc["group B"]
# Out:
#         math_score  read_score
# gender
# female   61.403846   71.076923
# male     65.930233   62.848837

# %%
data.groupby(["race/ethnicity","gender"]).math_score.nunique()
# Out:
# race/ethnicity  gender
# group A         female    29
#                 male      38
# group B         female    51
#                 male      43
# group C         female    59
#                 male      56
# group D         female    53
#                 male      49
# group E         female    44
#                 male      38
# Name: math_score, dtype: int64

# %%
data.sort_values(["gender","math_score"]).groupby("gender").head()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# 91     male        group C                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 76     male        group E            some high school      standard
# 596    male        group B                 high school  free/reduced
# 211    male        group C                some college  free/reduced
#
#     test_course  math_score  read_score  write_score
# 59         none           0          17           10
# 980        none           8          24           23
# ...

# %%
data["total_score"]=a

# %%
a=data.math_score+data.read_score+data.write_score

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_course  math_score  read_score  write_score  mixa  total score  \
# ...

# %%
data=data.assign(total_score_log=np.log(data.total_score))

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_course  math_score  read_score  write_score  mixa  total score  \
# ...

# %%
data.drop(["total_score"],axis=1)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_course  math_score  read_score  write_score  mixa  total score  \
# ...

# %%
dota=pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv")

# %%
dota[dota.legs==8].shape
# Out:
# (1, 8)

# %%
lupa=pd.read_csv("https://stepik.org/media/attachments/course/4852/accountancy.csv")

# %%
lupa.groupby(["Type","Executor"]).Salary.mean()
# Out:
# Type  Executor
# A     Loopa        58.000000
#       Pupa        160.833333
# B     Loopa       145.166667
#       Pupa         77.000000
# C     Loopa       154.333333
#       Pupa         74.500000
# D     Loopa       137.714286
#       Pupa        146.500000
# E     Loopa       164.000000
#       Pupa        131.200000
# F     Loopa       238.000000
#       Pupa        136.250000
# Name: Salary, dtype: float64

# %%
dota
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
dota.groupby(["attack_type","primary_attr"]).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
vodoros=pd.read_csv("http://stepik.org/media/attachments/course/4852/algae.csv")

# %%
vodoros.groupby("genus")[["alanin","citrate","glucose","oleic_acid"]].max()
# Out:
#                alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  0.875429  5.253527  3.414961    2.432526
# Cladophora   6.881024  6.940588  3.343707    2.829016
# Fucus        6.641303  6.423606  3.623225    6.405165
# Palmaria     3.176440  5.573905  3.242090    2.245538
# Saccharina   5.793163  5.621499  6.013219    4.817804

# %%
vodoros
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
vodoros.group.unique()
# Out:
# array(['brown', 'green', 'red'], dtype=object)

# %%
vodoros.groupby("group")["glucose"].max()
# Out:
# group
# brown    6.013219
# green    3.343707
# red      3.242090
# Name: glucose, dtype: float64

# %%
vodoros.groupby("group")["glucose"].min()
# Out:
# group
# brown    2.272724
# green    2.316955
# red      3.242090
# Name: glucose, dtype: float64

# %%
data.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
data.plot.scatter(x='math_score',y="read_score")
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='read_score'>

# %%
ax=sns.lmplot(x='math_score',y="read_score",hue="gender",data=data,fit_reg=False)

# %%
ax.set_xlabels("math")
ax.set_ylabels("read")

# %%
ax

# %%
sal=pd.read_csv("https://stepik.org/media/attachments/course/4852/income.csv")

# %%
sal
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
sns.lineplot(x=sal.index,y=sal.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
sal.plot()
# Out:
# <AxesSubplot:>

# %%
data=pd.read_csv("dataset_209770_61.txt",sep=" ")

# %%
data
# Out:
#               x            y
# 0     99.236019   516.298003
# 1    208.280696   202.524386
# 2   1003.315437  1399.038814
# 3    405.341598   902.068298
# 4   1108.876339   400.612098
# ..          ...          ...
# 85  1107.500220   402.056582
# 86  1096.184360   394.087429
# 87    90.494591   480.524128
# 88  1394.027445   686.323856
# 89   100.489416   504.848925
#
# [90 rows x 2 columns]

# %%
data.plot.scatter(x="x",y="y")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
vidi=pd.read_csv("https://stepik.org/media/attachments/course/4852/genome_matrix.csv",index_col=0)

# %%
vidi
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(vidi)
# Out:
# <AxesSubplot:>

# %%
dota=pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv",index_col=0)

# %%
dota["nroles"]=[len(x.split()) for x in dota['roles'].tolist()]

# %%
dota
# Out:
#     attack_type   id  legs  localized_name                          name  \
# 0         Melee    1     2       Anti-Mage        npc_dota_hero_antimage
# 1         Melee    2     2             Axe             npc_dota_hero_axe
# 2        Ranged    3     4            Bane            npc_dota_hero_bane
# 3         Melee    4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4        Ranged    5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
# ..          ...  ...   ...             ...                           ...
# 112       Melee  114     2     Monkey King     npc_dota_hero_monkey_king
# 113      Ranged  119     2     Dark Willow     npc_dota_hero_dark_willow
# 114       Melee  120     2       Pangolier       npc_dota_hero_pangolier
# 115      Ranged  121     2      Grimstroke      npc_dota_hero_grimstroke
# 116       Melee  129     2            Mars            npc_dota_hero_mars
#
#     primary_attr                                              roles  nroles
# ...

# %%
dota.nroles.hist()
# Out:
# <AxesSubplot:>

# %%
flow=pd.read_csv("https://stepik.org/media/attachments/course/4852/iris.csv",index_col=0)

# %%
flow["petal length"].hist()
# Out:
# <AxesSubplot:>

# %%
for col in flow.columns:
    print(max(flow[col])-min(flow[col]),col)
# Out:
# 3.6000000000000005 sepal length
# 2.4000000000000004 sepal width
# 5.9 petal length
# 2.4 petal width
# 2 species

# %%
flow[["petal length"]].boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x=flow["petal length"])
# Out:
# <AxesSubplot:xlabel='petal length'>

# %%
sns.pairplot(flow)

# %%
a=pd.DataFrame([])

# %%
my_data=pd.DataFrame({"type":pd.Series(["A","A","B","B"]),"value":pd.Series([10,14,12,23])})

# %%
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1060/391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined
